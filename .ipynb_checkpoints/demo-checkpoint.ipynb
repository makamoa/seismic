# %%
import h5py
import os
import glob
import torch
import numpy as np
from skimage import io, transform
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
imagenet_mean = mean = np.array([0.485, 0.456, 0.406])
imagenet_std = [0.229, 0.224, 0.225]
normalize = transforms.Normalize(imagenet_mean, imagenet_std)

# %%
from data import DerainLoader
from utils import *
derain_dir = "/home/makam0a/Dropbox/projects/denoising/Restormer/Deraining/Datasets/train/Rain13K"
derain_dataset = DerainLoader(derain_dir, transform=transforms.Compose([RandomCrop(target_size=(100,100)), ToTensor()]))

# %%
workers = 1
batch_size = 10000
dataloader = DataLoader(derain_dataset, batch_size=batch_size, shuffle=True, num_workers=workers)

# %%
sample = iter(dataloader).next()
sample

# %%
sample = iter(dataloader).next()

def show(sample, idx=0, axes=None):
    input = sample['input'][idx]
    target = sample['target'][idx]
    print(input.shape)
    if axes is None:
        fig, axes = plt.subplots(1,2, figsize=[20,10])
    axes[0].imshow(input)
    axes[1].imshow(target)

show(sample)
# Out:
# torch.Size([100, 100, 3])

# %%
derain_mean = sample['input'].mean(axis=[0,1,2])

# %%
torch.cuda.is_available()
# Out:
# False
